# %% [markdown]
# # <center> Visão Computacional — Neurônio Artificial</center>
#
# ---
#
# ##  O que é um Neurônio Artificial?
#
# Um **neurônio artificial** é uma unidade computacional que imita o comportamento dos neurônios biológicos.
# Ele recebe entradas, aplica pesos, soma tudo com um viés e passa esse valor por uma função de ativação.
#
# ## Tensorflow.keras
#
# **Tensorflow** é uma biblioteca de código aberto do Google para machine learning e Deep Learning, permite criar e treinar modelos de IA, manipulando dados em tensores (array multidimensionais) e oferecendo ferramentas flexíveis para pesquisadores e desenvolvedores, sendo usada em serviços como Busca e Tradutor.
#
# ![keras.png](attachment:keras.png)
#
# ## **Comandos**
#
# ### **Input**
# Representa a entrada da rede neural.
# Serve para dizer qual é o formato dos dados que vão entrar no modelo.
#  - Define o tamanho da imagem
#  - É sempre o primeiro bloco da rede
#  - Não tem pesos só descreve o formato
#
# ### **Flatten**
# Transforma uma matriz (imagem) em um vetor único. Imagens têm formato (altura, largura, canais)
# É necessário quando você vai conectar a imagem em camadas densas
#
# ### **GlobalAverage**
#
# ### **Maxpooling**
# Reduz o tamanho da imagem pegando apenas o valor máximo dentro de janelas
#
# `pool = MaxPooling(pool_size=(2,2))(conv)`
#
# Isso diminui a resolução, reduz parâmetros, retém as características mais importantes, ajuda a evitar overfitting
#
# ![resumo.png](attachment:resumo.png)
#
# ### **Dropout**
#
# ### **Conv2D**
# É a camada convolucional, usada para identificar padrões em imagens:
# - Arestas
# - Curvas
# - Texturas
# - Objetos
# Ela aplica **filtros** (kernels) pela imagem
#
# `conv = Conv2D(32, kernel_size=(3,3), activation='relu')(input)`
#
# Onde,
# - 32 filtros
# - Kernels 3x3
# - Cada filtro cria um mapa de características (feature map)
#
# ### **Camada Dense**
#
# A camada **Dense** (totalmente conectada) conecta **todos os neurônios da camada atual a todos os neurônios da camada anterior**.
# É uma camada fundamental em redes neurais, usada para aprender padrões complexos nos dados.
#
# ---
#
# **Fórmula**
#
# `saida = activation((W * x) + b)`
#
#
# Onde:
# - **activation** → função de ativação aplicada elemento a elemento
# - **W * x** → multiplicação matricial entre entrada e kernel (pesos)
# - **b** → vetor de bias
#
# ---
#
#   **Exemplo**
#
# ```python
# densa = Dense(128, activation='relu')(x)
# ```
#
# - Usada para classificação no final da rede
# - Pode ter ReLU, Softmax, Sigmoid etc.
#
#  **Características**
#
# - Usada normalmente **no final da rede** para classificação
# - Aceita ativações como **ReLU**, **Softmax**, **Sigmoid**, etc.
#
# --
#
#  **Parâmetros**
# ```python
#   dense = layers.Dense(
#     units = 128,                           # *obrigatório* Número de neurônios da camada
#     activation = 'relu'                    # *opcional* Função de ativação (`relu`, `sigmoid`, `softmax`, `tanh`, etc.).
#     use_bias=True,                         # *(default: True)* Indica se um vetor de bias será usado.
#     kernel_initializer="glorot_uniform",   # Inicialização dos pesos (ex.: `glorot_uniform`, `he_normal`).
#     bias_initializer="zeros",              # *(default: zeros)* Inicialização do bias.
#     kernel_regularizer=None,               # Regularização aplicada aos pesos (`l1`, `l2`, etc.).
#     bias_regularizer=None,                 # Regularização aplicada ao bias.
#     activity_regularizer=None,             # Regularização aplicada à saída da camada.
#     kernel_constraint=None,                # Restrições aplicadas aos pesos (ex.: norma máxima).
#     bias_constraint=None                   # Restrições aplicadas ao bias (ex.: norma máxima).
#
#   )
# ```
#
#
# ## Referências para olhar depois
#
# https://dingyan89.medium.com/calculating-parameters-of-convolutional-and-fully-connected-layers-with-keras-186590df36c6
#
# #  Função de Ativação
#
# Após calcular \(S\), o valor passa por uma **função de ativação**, que decide a saída final do neurônio. Imagine que cada neurônio da rede neural é como uma *pessoa tomando uma decisão*.
#
# 1. Ela recebe informações (números)
# 2. Faz uma conta (soma + pesos)
# 3. Decide se passa adiante ou não.
#
# Em resumo, é a decisão, dão " *inteligência* ". Sem ela a rede só faria contas lineares e não aprenderia coisas complexas como imagens, voz, texto, padrões. Além disso, ela decide quanto e quais neurônios deve ativar.
#
# A função de ativação funciona da mesma forma em Dense e Conv2D, o que muda é o tipo de dado que chega até ela.
#
# ***Camadas internas aprendem padrões,
# Camada final responde a pergunta***
#
#
# ## **ReLU (Rectified Linear Unit)**
#
# `f(x) = max(0, x)`
#
# Ela transforma cada neurônio em um interruptor inteligente. Se o padrão não existe, neurônio fica desligado. Se o padrão existe, neurônio passa o sinal inteiro.
#
# - Se o valor for negativo, **vira 0**,
# - Se o valor for positivo, **continua igual**
#
# Em resumo, não "ameniza", não "suaviza", deixa passar cru. Assim, ela cria esparsidade e muitos neurônios ficam em zero. Isso significa que, só alguns neurônios "falam", outros ficam quietos e a rede aprende quais padrões importam.
#
# Em Dense, cada neurônio só responde se detectar algo relevante nos dados de entrada, aprendendo combinações não-lineares de features e criando limites de decisão complexos.
#
# Em Conv2D, o filtro detecta um padrão (borda, textura, curva) e a função remove ativações fracas (negativas) e mantém apenas padrões fortes.
#
# **Quando usar:**
#  - Camadas internas ou ocultas
#  - Redes profundas
#  - CNNs (imagens, vídeo)
#  Se não sabe qual usar, use ReLU.
#
#  **Quando não usar**:
#  - Na camada final, a camada de saída é de classificação probabilística
#  - Quando precisa de saída negativa
#  - Em problemas muito sensíveis a neurônios mortos
#
#  Se o neurônio só recebe valores negativos -> saída sempre 0 -> gradiente 0 -> nunca aprende.
#
# ## **Sigmoid**
#
# *Qual a probabilidade disso ser verdadeiro?*
#
# É uma função que comprime qualquer valor real para o intervalor 0 - 1. Possui forma de "S".
#
# Sua principal função é converter qualquer valor de entrada (um número real) em uma saída suave e contínua que está sempre no intervalo entre 0 e 1.
# - Se o valor de entrada for muito negativo, a saída será próxima de 0.
# - Se o valor de entrada for muito positivo, a saída será próxima de 1.
# - Se o valor estiver próximo de 0, a saída estará próxima de 0,5.
#
# Essa função satura facilmente, em entradas grandes possui um gradiente quase zero e assim a rede para de aprender. Por isso, esse é o grande problema dela em camadas ocultas.
#
# Em Dense, é usada quase exclusivamente na última camada pois funciona com classificação binária.
# Em Conv2D, é raramente usada porém pode aparecer em máscaras (segmentação binária) e attention gates, mas nunca em camadas intermediárias.
#
# **Quando usar:**
# - Saída binária
# - Probabilidade de evento
# - Logistic Regression Neural
#
# **Quando não usar:**
# - Camadas ocultas
# - CNNs intermediárias
# - Redes grandes
#
# ## **Tahn (Tangente Hiperbólica)**
# É uma versão centrada no zero da Sigmoid, possui um intervalo de -1 a 1.
#
# É melhor que a Sigmoid pois os dados ficam mais balanceados, porém ainda sofre de *vanishing gradient*. Hoje é frequentemente substituída pela ReLu.
#
# **Quando usar:**
# - Dados normalizados entre -1 e 1
# - Redes pequenas
# - Alguns casos em RNNs
#
# **Quando não usar:**
# - Redes profundas
# - CNNs modernas
#
# Na dúvida, vai de ReLU.
#
# ## **Softmax**
# Transforma um vetor de números em uma distribuição de probabilidade
#
# Na prática os neurônios competem entre si. Quanto maior um, menor os outros. Por isso, é uma função usada somente na saída para classificação de multiclasse.
#
# Em Dense, cada saída é uma probabilidade de uma classe que soma no total 1.
# Em Conv2D, não se usa diretamente:
# Conv -> flatten -> Dense -> Softmax
#
# **Quando usar:**
# - Classificação multiclasse exclusiva
# - Uma única classe correta
#
# **Quando não usar:**
#  - Classificação multilabel
#  - Problemas de regressão.
#
#  ## **Linear**
#
#  A linear não altera o valor. O neurônio apenas entrega a soma ponderada, por isso é usada exclusivamente na saída de regressão.
#  Não é comumente usada em Conv2D.
#
#  **Quando usar:**
# - Regressão (temperatura, preço, idade)
# - Valores contínuos
#
#  **Quando não usar:**
# - Camadas ocultas
#
# ##  Função de Erro (Loss Function)
#
# A função de erro mede o quão distante está o resultado desejado:
#
# dE/dw = (dE/dy) * (dy/dS) * (dS/dw)
#
# Onde:
#
# - \(t\) = *target* (o valor desejado)
# - \(y\) = saída do neurônio após a ativação
#
#
#
# ## Ajuste dos Pesos (Backpropagation)
#
# O objetivo é ajustar o peso **w** para minimizar o erro.
#
# Para isso, usamos a **regra da cadeia**, que permite quebrar derivadas complexas em partes menores.
#
# Exemplo simples da regra da cadeia:
#
# Se:
# u(x) = (x + 1) * 4
#
# Então:
# du/dx = 4
#
#
# ### Aplicando ao neurônio
#
# A derivada do erro em relação ao peso é:
#
# dE/dw = (dE/dy) * (dy/dS) * (dS/dw)
#
# Interpretação de cada termo:
#
# 1. **dE/dy** — quanto o erro muda quando a saída y muda
# 2. **dy/dS** — quanto a função de ativação muda quando S muda
# 3. **dS/dw** — quanto a soma ponderada S muda quando o peso w muda
#
# Como:
#
# S = (w * x) + b
#
# Então:
#
# dS/dw = x
#
#
# ##  Recursos Visuais
#
# Fórmulas:
#
# 🔗 https://excalidraw.com/#room=2e2f0832aab9b8c40d36,Qn0tn30UH_lvd19ZgVcO3A

# %% [markdown]
# # **Código**

# %%
from tensorflow.keras import models, layers

model = models.Sequential([
    
])
